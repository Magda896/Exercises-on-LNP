# %%
file = open("dataset.txt", "rt")
data = file.read()

# %%
data
# Out:
# 'Return of the Coronavirus: 2019-nCoV\n\nLisa E. Gralinski and Vineet D. Menachery\n\nAbstract: The emergence of a novel coronavirus (2019-nCoV) has awakened the echoes of SARS-CoV\nfrom nearly two decades ago. Yet, with technological advances and important lessons gained from\nprevious outbreaks, perhaps the world is better equipped to deal with the most recent emergent\ngroup 2B coronavirus.\n\nKeywords: 2019-nCoV; novel CoV; Wuhan; Wuhan pneumonia; coronavirus; emerging viruses;\nSARS-CoV; MERS-CoV\n\n1. Emergence\n\nThe third zoonotic human coronavirus (CoV) of the century emerged in December 2019, with\na cluster of patients with connections to Huanan South China Seafood Market in Wuhan, Hubei\nProvince, China. Similar to severe acute respiratory syndrome coronavirus (SARS-CoV) and Middle\nEast respiratory syndrome coronavirus (MERS-CoV) infections, patients exhibited symptoms of viral\npneumonia including fever, diﬃculty breathing, and bilateral lung inﬁltration in the most sev
# ...

# %%
pip install nltk
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 3.6 MB/s eta 0:00:01     |▊                               | 30 kB 3.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 722 kB 70.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 9.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 75 kB 7.4 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.corpus import stopwords

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
text_tokens = word_tokenize(data)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

#print(tokens_without_sw)
words1 = [word for word in tokens_without_sw if word.isalpha()]
print(words1[:100])
# Out:
# ['Return', 'Coronavirus', 'Lisa', 'Gralinski', 'Vineet', 'Menachery', 'Abstract', 'The', 'emergence', 'novel', 'coronavirus', 'awakened', 'echoes', 'nearly', 'two', 'decades', 'ago', 'Yet', 'technological', 'advances', 'important', 'lessons', 'gained', 'previous', 'outbreaks', 'perhaps', 'world', 'better', 'equipped', 'deal', 'recent', 'emergent', 'group', 'coronavirus', 'Keywords', 'novel', 'CoV', 'Wuhan', 'Wuhan', 'pneumonia', 'coronavirus', 'emerging', 'viruses', 'Emergence', 'The', 'third', 'zoonotic', 'human', 'coronavirus', 'CoV', 'century', 'emerged', 'December', 'cluster', 'patients', 'connections', 'Huanan', 'South', 'China', 'Seafood', 'Market', 'Wuhan', 'Hubei', 'Province', 'China', 'Similar', 'severe', 'acute', 'respiratory', 'syndrome', 'coronavirus', 'Middle', 'East', 'respiratory', 'syndrome', 'coronavirus', 'infections', 'patients', 'exhibited', 'symptoms', 'viral', 'pneumonia', 'including', 'fever', 'diﬃculty', 'breathing', 'bilateral', 'lung', 'inﬁltration', 'severe
# ...

# %%
from collections import Counter

# %%
split_it = str(words1).split()

# %%
Counter = Counter(split_it)

# %%
most_occur = Counter.most_common(10)

# %%
print(most_occur)
# Out:
# [("'human',", 32), ("'cases',", 30), ("'outbreak',", 19), ("'CoV',", 18), ("'virus',", 18), ("'Wuhan',", 16), ("'patients',", 16), ("'disease',", 15), ("'The',", 14), ("'health',", 14)]

# %%
from textblob import TextBlob
blob = TextBlob(str(words1))
print(blob.noun_phrases)
# Out:
# ["[ 'return"]

# %%
pip install TextBlob
# Out:
# ...
#      |████████████████████████████████| 636 kB 4.8 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
import nltk 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
def ProperNounExtractor(text):
    
    
    counter=0
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        words = [word for word in words if word not in set(stopwords.words('english'))]
        tagged = nltk.pos_tag(words)
        for (word, tag) in tagged:
            if tag == 'NNP': # If the word is a proper noun
                counter=counter+1
                #print(word)
        print('The article has' +' ' +str(counter)+' '+'nouns')

# %%
text = str(words1)
# Calling the ProperNounExtractor function to extract all the proper nouns from the given text. 
ProperNounExtractor(text)
# Out:
# The article has 921 nouns

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True
